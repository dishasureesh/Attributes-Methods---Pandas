# %%
import numpy as np
import pandas as pd

# %%
# reading files using pandas
salaries = pd.read_csv("/content/Salaries (1).csv")

# %%
# Using attributes to understand the characteristics of the dataset-salaries.
# Understanding the type of data present in each column
salaries.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
#The column names in the dataframe
salaries.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#Dimensions of the dataframe
salaries.ndim
# Out:
# 2

# %%
#Number of rows and columns
salaries.shape
# Out:
# (78, 6)

# %%
#Number of elements
salaries.size
# Out:
# 468

# %%
#Using methods to work in the dataset
#first 5 rows values to get a brief view of the dataframe
salaries.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#last 5 rows
salaries.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
#max and min values in each of the column
salaries.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
salaries.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
# mean, median and standard deviation values for each of the column (only columns containing numerical values)
salaries.mean()
# Out:
# <ipython-input-38-e70892c78636>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   salaries.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
salaries.median()
# Out:
# <ipython-input-39-d0d1f0e8b82e>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   salaries.median()
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
salaries.std()
# Out:
# <ipython-input-40-a026ebf2bcbf>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   salaries.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
#random sample of the dataframe
salaries.sample(5)
# Out:
#          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 73       Prof          B   18       10  Female  105450
# 5        Prof          A   20       20    Male  122400
# 30  AssocProf          B    9        7    Male  107008
# 26       Prof          A   38       19    Male  148750

# %%
#check for missing values
salaries.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
#drop all records with missing values
salaries.dropna()
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#selecting column in the dataset
salaries['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
salaries[['rank']]
# Out:
#          rank
# 0        Prof
# 1        Prof
# 2        Prof
# 3        Prof
# 4        Prof
# ..        ...
# 73       Prof
# 74  AssocProf
# 75       Prof
# 76       Prof
# 77       Prof
#
# [78 rows x 1 columns]

# %%
#Dataframes groupby() method
salaries.groupby('rank').mean()
# Out:
# <ipython-input-51-aa2f77e566e6>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   salaries.groupby('rank').mean()
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
salaries.groupby(['rank'])[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
#Filtering
#Selecting only those rows that contain female professors.
female_prof = salaries[salaries['sex']=='Female']
female_prof
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
#Slicing , dataframe =[[rows,column]]
#iloc method , Dataframe[start:stop-1, start:stop-1]
# Get first 3 rows and first 6 columns
salaries_slicing =salaries.iloc[0:3,0:6]
salaries_slicing
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515

# %%
#Describe method to get summary of the dataframe
salaries.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000
